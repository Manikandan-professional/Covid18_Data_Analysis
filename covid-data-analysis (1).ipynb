# %% [markdown]
# **Latest Covid-19 India Statewise Data**

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/d/anandhuh/latest-covid19-india-statewise-data/Latest Covid-19 India Status.csv

# %% [markdown]
# **About the Dataset**
#
# * This dataset contains latest Covid-19 India state-wise data as on August 18, 2021. This dataset can be used to analyze covid condition in India.
#
# * This dataset is great for Exploratory Data Analysis
#
# * Attribute Information
#
# * State/UTs - Names of Indian States and Union Territories.
#
# * Total Cases - Total number of confirmed cases
#
# * Active - Total number of active cases
#
# * Discharged - Total number of discharged cases
#
# * Deaths - Total number of deaths
#
# * Active Ratio (%) - Ratio of number of active cases to total cases
#
# * Discharge Ratio (%) - Ratio of number of discharged cases to total cases
#
# * Death Ratio (%) - Ratio of number of deaths to total cases**

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import matplotlib.pyplot as plt

# %% [markdown]
# Importing the necessary modules pyplot is for graphical interface and representation, figure is set for size of the output of the figure with pixels

# %% [markdown]
# **Gathering the Information from the Datasets**

# %%
df=pd.DataFrame(pd.read_csv("../input/d/anandhuh/latest-covid19-india-statewise-data/Latest Covid-19 India Status.csv"))
df
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 0                        Andaman and Nicobar         7566       6        7431
# 1                             Andhra Pradesh      2014116   14693     1985566
# 2                          Arunachal Pradesh        53031     863       51908
# 3                                      Assam       589426    6901      576865
# 4                                      Bihar       725708     100      715955
# 5                                 Chandigarh        65105      40       64252
# 6                               Chhattisgarh      1004451     412      990484
# 7   Dadra and Nagar Haveli and Daman and Diu        10663       4       10655
# 8                                      Delhi      1437764     349     1412333
# 9                                        Goa       173955     877      169877
# 10                                   Gujarat       825422     150      815191
# ...

# %% [markdown]
# **Here below we are going to compare all the features with the particular state which is headed above which helps us in identifying the current status of the covid of that particlar State/UTs.**

# %% [markdown]
# # **Analysis of State/UTs with the Total Cases**

# %%
def addlabels(x,y):
    for i in range(len(x)):
        plt.text(i, y[i], y[i], ha = 'center',color='red',fontsize=15)
figure(figsize=(25,15),dpi=80)
ax = plt.axes()
ax.set_facecolor("black")
a=plt.plot(df['State/UTs'],df['Total Cases'],color='white',linewidth=1)
b=plt.scatter(df['State/UTs'],df['Total Cases'],color='red',s=30)
addlabels(df['State/UTs'],df['Total Cases'])
plt.xlabel("State/UTs",color='blue',fontsize=20)
plt.ylabel("Total Cases",color='blue',fontsize=20)
plt.xticks(rotation=90,fontsize=15)
plt.title("Analysis of State/UTs with the Total cases statistics",color='blue',fontsize=25)
plt.show()

# %% [markdown]
# # **Analysis of State/UTs with the Active Cases**

# %%
def addlabels(x,y):
    for i in range(len(x)):
        plt.text(i, y[i], y[i], ha = 'left',color='white',fontsize=15)
figure(figsize=(25,15),dpi=80)
ax = plt.axes()
ax.set_facecolor("black")
c=plt.plot(df['State/UTs'],df['Active'],color='silver',linewidth=1)
d=plt.scatter(df['State/UTs'],df['Active'],color='red',s=30)
addlabels(df['State/UTs'],df['Active'])
plt.xlabel("State/UTs",color='blue',fontsize=20)
plt.ylabel("Active",color='blue',fontsize=20)
plt.xticks(rotation=90,fontsize=15)
plt.title("Analysis of State/UTs with the Active cases statistics",color='blue',fontsize=25)
plt.show()

# %% [markdown]
# # **Analysis of State/UTs with the Discharged Cases**

# %%
def addlabels(x,y):
    for i in range(len(x)):
        plt.text(i, y[i], y[i], ha = 'right',color='white',fontsize=15)
figure(figsize=(25,15),dpi=80)
ax = plt.axes()
ax.set_facecolor("black")
plt.plot(df['State/UTs'],df['Discharged'],color='silver',linewidth=1)
plt.scatter(df['State/UTs'],df['Discharged'],color='red',s=30)
addlabels(df['State/UTs'],df['Discharged'])
plt.xlabel("State/UTs",color='blue',fontsize=20)
plt.ylabel("Discharged",color='blue',fontsize=20)
plt.xticks(rotation=90,fontsize=15)
plt.title("Analysis of State/UTs with the Discharged cases statistics",color='blue',fontsize=25)
plt.show()

# %% [markdown]
# # **Analysis of State/UTs with the Number of Deaths**

# %%
def addlabels(x,y):
    for i in range(len(x)):
        plt.text(i, y[i], y[i], ha = 'right',color='white',fontsize=13)
figure(figsize=(25,15),dpi=80)
ax = plt.axes()
ax.set_facecolor("black")
plt.plot(df['State/UTs'],df['Deaths'],color='silver',linewidth=1)
plt.scatter(df['State/UTs'],df['Deaths'],color='red',s=30)
addlabels(df['State/UTs'],df['Deaths'])
plt.xlabel("State/UTs",color='blue',fontsize=20)
plt.ylabel("Deaths",color='blue',fontsize=20)
plt.xticks(rotation=90,fontsize=15)
plt.title("Analysis of State/UTs with the number of death statistics",color='blue',fontsize=25)
plt.show()

# %% [markdown]
# # **Analysis of State/UTs with the Active Ratio**

# %%
def addlabels(x,y):
    for i in range(len(x)):
        plt.text(i, y[i], y[i], ha = 'right',color='white',fontsize=15)
figure(figsize=(25,15),dpi=80)
ax = plt.axes()
ax.set_facecolor("black")
plt.plot(df['State/UTs'],df['Active Ratio (%)'],color='silver',linewidth=1)
plt.scatter(df['State/UTs'],df['Active Ratio (%)'],color='red',s=30)
addlabels(df['State/UTs'],df['Active Ratio (%)'])
plt.xlabel("State/UTs",color='blue',fontsize=20)
plt.ylabel("Active Ratio (%)",color='blue',fontsize=20)
plt.xticks(rotation=90,fontsize=15)
plt.title("Analysis of State/UTs with the Total cases statistics",color='blue',fontsize=25)
plt.show()

# %% [markdown]
# # **Analysis of State/UTs with the Discharge Ratio**

# %%
def addlabels(x,y):
    for i in range(len(x)):
        plt.text(i, y[i], y[i], ha = 'right',color='white',fontsize=13)
figure(figsize=(25,15),dpi=80)
ax = plt.axes()
ax.set_facecolor("black")
plt.plot(df['State/UTs'],df['Discharge Ratio (%)'],color='silver',linewidth=1)
plt.scatter(df['State/UTs'],df['Discharge Ratio (%)'],color='red',s=30)
addlabels(df['State/UTs'],df['Discharge Ratio (%)'])
plt.xlabel("State/UTs",color='blue',fontsize=20)
plt.ylabel("Discharge Ratio (%)",color='blue',fontsize=20)
plt.xticks(rotation=90,fontsize=15)
plt.title("Analysis of State/UTs with the Discharge Ratio (%) statistics",color='blue',fontsize=25)
plt.show()

# %% [markdown]
# # **Analysis of State/UTs with the Death Ratio**

# %%
def addlabels(x,y):
    for i in range(len(x)):
        plt.text(i, y[i], y[i], ha = 'right',color='white',fontsize=13)
figure(figsize=(25,15),dpi=80)
ax = plt.axes()
ax.set_facecolor("black")
plt.plot(df['State/UTs'],df['Death Ratio (%)'],color='silver',linewidth=1)
plt.scatter(df['State/UTs'],df['Death Ratio (%)'],color='red',s=30)
addlabels(df['State/UTs'],df['Death Ratio (%)'])
plt.xlabel("State/UTs",color='blue',fontsize=20)
plt.ylabel("Death Ratio (%)",color='blue',fontsize=20)
plt.xticks(rotation=90,fontsize=15)
plt.title("Analysis of State/UTs with the Death Ratio (%) statistics",color='blue',fontsize=25)
plt.show()

# %% [markdown]
# # **Thank you !!!!!!!**
